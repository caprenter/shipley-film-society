# %%
# import required module
import os
# assign directory
directory = '/home/david/Documents/ShipleyFilmSociety_Web/htdocs'

# iterate over files in
# that directory
# for filename in os.listdir(directory):
	# f = os.path.join(directory, filename)
	# checking if it is a file
	#if os.path.isfile(f):
	#print(f)

# Get list of all files in a given directory sorted by name
list_of_files = sorted( filter( lambda x: os.path.isdir(os.path.join(directory, x)), os.listdir(directory) ) )

for dir_name in list_of_files:
    #print(dir_name)

		

		f = os.path.join(directory, dir_name)
		# checking if it is a file
		#if os.path.isfile(f):
		print(f)
	
	#f = os.path.join(list_of_files, file_name)
	# checking if it is a file
	#if os.path.isfile(f):
	#	print(f)
# Out:
# /home/david/Documents/ShipleyFilmSociety_Web/htdocs/Aesthetica
# /home/david/Documents/ShipleyFilmSociety_Web/htdocs/about-us
# /home/david/Documents/ShipleyFilmSociety_Web/htdocs/actofkilling
# /home/david/Documents/ShipleyFilmSociety_Web/htdocs/aprophet
# /home/david/Documents/ShipleyFilmSociety_Web/htdocs/asunder
# /home/david/Documents/ShipleyFilmSociety_Web/htdocs/bandeapart
# /home/david/Documents/ShipleyFilmSociety_Web/htdocs/barbara
# /home/david/Documents/ShipleyFilmSociety_Web/htdocs/biglebowski
# /home/david/Documents/ShipleyFilmSociety_Web/htdocs/bpm
# /home/david/Documents/ShipleyFilmSociety_Web/htdocs/breathing
# /home/david/Documents/ShipleyFilmSociety_Web/htdocs/burntbythesun
# /home/david/Documents/ShipleyFilmSociety_Web/htdocs/captainfantastic
# /home/david/Documents/ShipleyFilmSociety_Web/htdocs/catchmedaddy
# /home/david/Documents/ShipleyFilmSociety_Web/htdocs/childrenandfim
# /home/david/Documents/ShipleyFilmSociety_Web/htdocs/contact-form
# ...

# %%
import os
rootdir = '/home/david/Documents/ShipleyFilmSociety_Web/htdocs'

for subdir, dirs, files in os.walk(rootdir):
    for file in files:
        print(os.path.join(subdir, file))
# Out:
# /home/david/Documents/ShipleyFilmSociety_Web/htdocs/index.html
# /home/david/Documents/ShipleyFilmSociety_Web/htdocs/sitemap.xml
# /home/david/Documents/ShipleyFilmSociety_Web/htdocs/films.txt
# /home/david/Documents/ShipleyFilmSociety_Web/htdocs/files/lebowskilisting.jpg
# /home/david/Documents/ShipleyFilmSociety_Web/htdocs/files/stacks-image-e5e5909-430x242@2x.jpg
# /home/david/Documents/ShipleyFilmSociety_Web/htdocs/files/stacks-image-1fa6fd0-632x356.jpg
# /home/david/Documents/ShipleyFilmSociety_Web/htdocs/files/stacks-image-52fbbfc-632x332.jpg
# /home/david/Documents/ShipleyFilmSociety_Web/htdocs/files/stacks-image-f7cc556.jpg
# /home/david/Documents/ShipleyFilmSociety_Web/htdocs/files/dheepanlisting.jpg
# /home/david/Documents/ShipleyFilmSociety_Web/htdocs/files/stacks-image-ae6fe82-1012x674.jpg
# /home/david/Documents/ShipleyFilmSociety_Web/htdocs/files/edukatorslisting.jpg
# /home/david/Documents/ShipleyFilmSociety_Web/htdocs/files/delicatessen@2x.jpg
# ...

# %%
import os
rootdir = '/home/david/Documents/ShipleyFilmSociety_Web/htdocs'

def lines_that_equal(line_to_match, fp):
    return [line for line in fp if line == line_to_match]

def lines_that_contain(string, fp):
    return [line for line in fp if string in line]

def lines_that_start_with(string, fp):
    return [line for line in fp if line.startswith(string)]

def lines_that_end_with(string, fp):
    return [line for line in fp if line.endswith(string)]



for subdir, dirs, files in os.walk(rootdir):
    dirs.sort()
    for file in sorted(files):
        if file == 'index.html':
            #with open(os.path.join(subdir, file), "r") as fp:
                #f#or line in lines_that_contain("background-image", fp):
                    #print (subdir)
                    #print (line)
            with open(os.path.join(subdir, file), "r") as fp:
                for line in lines_that_contain("youtube", fp):
                    print (subdir + line)
                    #print (line)
            #with open(os.path.join(subdir, file), "r") as fp:
                #for line in lines_that_contain("stacks_in text_stack", fp):
                    #print (subdir)
                    #print (line)
# Out:
# /home/david/Documents/ShipleyFilmSociety_Web/htdocs/actofkilling<iframe width="560" height="315" src="https://www.youtube.com/embed/SD5oMxbMcHM" frameborder="0" allowfullscreen></iframe>
#
# /home/david/Documents/ShipleyFilmSociety_Web/htdocs/aprophet<iframe width="560" height="315" src="https://www.youtube.com/embed/YWmIpiEJ1ms?rel=0&amp;showinfo=0" frameborder="0" allowfullscreen></iframe>
#
# /home/david/Documents/ShipleyFilmSociety_Web/htdocs/asunder<iframe width="640" height="360" src="https://www.youtube.com/embed/JXotucIFYZ0" frameborder="0" allowfullscreen></iframe>
#
# /home/david/Documents/ShipleyFilmSociety_Web/htdocs/barbara<iframe width="560" height="315" src="https://www.youtube.com/embed/q_Pn9zwhJtI" frameborder="0" allow="autoplay; encrypted-media" allowfullscreen></iframe>
#
# ...

# %%
N = 3
with open('/home/david/Documents/ShipleyFilmSociety_Web/data.txt', 'r') as f:
    lines = f.read().splitlines()
    for i, line in enumerate(lines):
        if "30pm" in line: 
            j = i-N if i>N else 0
            for k in range(j,i+1):
                print(lines[k])
# Out:
# Smoke
# Certificate 15
# Friday 3 April 2020
# Doors open 7.30pm, film starts 8pm
#
# Man with a Movie Camera
# Certificate: U
# Friday 4 October 2019, 7.30pm
#
# Delicatessen
# Certificate: 15
# Saturday 28th October 2017, 7.30pm
# Trollhunter
# (Trolljegeren)
# Certificate: 15
# Friday 18th March 2016, 7.30pm
#
#  Aesthetica Short Film Festival Tour
#  Certificate: 15
#  Friday 6th September 2019, doors open 7.30pm
#
# A Story of Children and Film
# Certificate: PG
# Friday 9th December 2016, 7.30pm
#
#  Captain Fantastic
# Certificate: 15
# Saturday 25th November 2017, 7.30pm
# Waste Land
# A benefit for the Bradford Metropolitan Food Bank
# Certificate: PG
# Friday 13th January 2017, 7.30pm
#
# Memories of a Murder
# Certificate: 15
# Saturday 30th September 2017, 7.30pm
#
# The Act of Killing
# Certificate: 15
# Friday 10th February 2017, 7.30pm
#
# Nae Pasaran
# Certificate: 15
# Friday 18th January 2019, 7.30pm
#
# ...
